# %% [markdown]
# # Animating trips with pydeck
#
# - Pydeck documentation for `TripsLayers`: https://deckgl.readthedocs.io/en/latest/gallery/trips_layer.html
#
# - Stackoverflow example for pydeck
# https://stackoverflow.com/questions/65865145/animating-tripslayer-in-deck-gl-with-python
#
# - Example of Trip Layer with Deck
# https://deck.gl/examples/trips-layer/

# %%
import geopandas as gpd
import pandas as pd
import pydeck as pdk
import time
import json

# %%
file = open("scraped_data/bus_positions.json")
bus_positions = json.load(file)
file.close()

bus_positions[0]["bustime-response"]["vehicle"][0]
# Out:
# {'vid': '7936',
#  'tmstmp': '20240130 22:12',
#  'lat': '41.730838775634766',
#  'lon': '-87.61434173583984',
#  'hdg': '359',
#  'pid': 18414,
#  'rt': '3',
#  'des': 'Michigan/Chicago',
#  'pdist': 6368,
#  'dly': False,
#  'tatripid': '393',
#  'origtatripno': '251981024',
#  'tablockid': 'N4  -793',
#  'zone': ''}

# %%
# Parsing data
# Leave only one vehicle 
a_single_bus_journey = []
# for snapshots in bus_positions:
for response in bus_positions: 
    if "vehicle" in response["bustime-response"]:
        for bus in response["bustime-response"]["vehicle"]: 
            if bus["vid"] == "1259": 
                bus["coordinates"] = [bus["lon"], bus["lat"]]
                a_single_bus_journey.append(bus)

# a_single_bus_journey

# %%
df_bus = pd.read_json(json.dumps(a_single_bus_journey))
# Out:
# /tmp/ipykernel_48219/1625725814.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_bus = pd.read_json(json.dumps(a_single_bus_journey))

# %%
df_bus["geometry"] = gpd.points_from_xy(df_bus.lon, df_bus.lat)
gdf_bus = gpd.GeoDataFrame(df_bus, geometry='geometry')
# gdf_bus

# %%
all_buses = []

for response in bus_positions: 
    if "vehicle" in response["bustime-response"]:
        for bus in response["bustime-response"]["vehicle"]: 
            bus["coordinates"] = [bus["lon"], bus["lat"]]
            all_buses.append(bus)

df_buses = pd.read_json(json.dumps(all_buses))
df_buses["geometry"] = gpd.points_from_xy(df_buses.lon, df_buses.lat)
gdf_buses = gpd.GeoDataFrame(df_buses, geometry='geometry')
gdf_buses
# Out:
# /tmp/ipykernel_48219/1647738045.py:9: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_buses = pd.read_json(json.dumps(all_buses))
#       vid          tmstmp                lat                lon  hdg    pid  \
# 0    7936  20240130 22:12 41.730838775634766 -87.61434173583984  359  18414
# 1    1359  20240130 22:11  41.73215103149414 -87.61438751220703  358  18414
# 2    1560  20240130 22:11 41.849849700927734  -87.6186294555664  334  18414
# 3    1299  20240130 22:12  41.86909866333008 -87.62401610729741  357  18414
# 4    8456  20240130 22:12           41.89386 -87.61999333333333  178  18415
# ..    ...             ...                ...                ...  ...    ...
# 569  1474  20240130 22:49  41.75149040222168 -87.66355361938477  182   1600
# 570  1451  20240130 22:50  41.74885377150316  -87.6634737454928  181   3637
# 571  8057  20240130 22:50  41.73936595916748 -87.66307067871094    0   9372
# 572  1575  20240130 22:50  41.86336090451195 -87.66625068301246  354   9372
# 573  1524  20240130 22:50 41.955979919433595 -87.66324272155762  335   9372
#
#     rt               des  pdist    dly  tatripid  origtatripno tablockid zone  \
# 0    3  Michigan/Chicago   6368  False       393     251981024  N4  -793
# 1    3  Michigan/Chicago   6845  False       394     251981859    3 -708
# 2    3  Michigan/Chicago  50057  False       391     251981919    4 -710
# 3    3  Michigan/Chicago  58480  False       389     251981635    3 -757
# 4    3     95th Red Line      0  False   1080326     251980537  N4  -792
# ..  ..               ...    ...    ...       ...           ...       ...  ...
# 569  9              95th  77864  False  10001944     252019054    9 -626
# 570  9              74th  10507  False  88357974     252019160    9 -608
# 571  9       Irving Park   7033  False  10001922     252017664  N9  -695
# 572  9       Irving Park  53003  False  10001924     252017349  N9  -694
# 573  9       Irving Park  88757  False  10001926     252017457  N9  -693
#
#                                   coordinates                    geometry
# 0    [-87.61434173583984, 41.730838775634766]  POINT (-87.61434 41.73084)
# 1     [-87.61438751220703, 41.73215103149414]  POINT (-87.61439 41.73215)
# 2     [-87.6186294555664, 41.849849700927734]  POINT (-87.61863 41.84985)
# 3     [-87.62401610729741, 41.86909866333008]  POINT (-87.62402 41.86910)
# 4              [-87.61999333333333, 41.89386]  POINT (-87.61999 41.89386)
# ..                                        ...                         ...
# 569   [-87.66355361938477, 41.75149040222168]  POINT (-87.66355 41.75149)
# 570    [-87.6634737454928, 41.74885377150316]  POINT (-87.66347 41.74885)
# 571   [-87.66307067871094, 41.73936595916748]  POINT (-87.66307 41.73937)
# 572   [-87.66625068301246, 41.86336090451195]  POINT (-87.66625 41.86336)
# 573  [-87.66324272155762, 41.955979919433595]  POINT (-87.66324 41.95598)
#
# [574 rows x 16 columns]

# %%
gdf_buses["tmstmp"]

# %%
gdf_buses["unix_tmstmp"] = gdf_buses["tmstmp"].astype('datetime64[s]').astype('int')
gdf_buses["unix_tmstmp"] = gdf_buses["unix_tmstmp"] - min(gdf_buses["unix_tmstmp"] )
gdf_buses["unix_tmstmp"] 

gdf_buses["vid"].unique()
# Out:
# array([7936, 1359, 1560, 1299, 8456, 7951, 7969, 1293, 1324, 8529, 1237,
#        8523, 1201, 1327, 1263, 1329, 1265, 7945, 1285, 1325, 1277, 8457,
#        7910, 8434, 8276, 4330, 8476, 4019, 4180, 4107, 4036, 1728, 8261,
#        1290, 1292, 1212, 7994, 1259, 8458, 8507, 7980, 8550, 1308, 7914,
#        1255, 8008, 1474, 1451, 8043, 8225, 1575, 1524, 1024, 8077, 7925,
#        8557, 8057])

# %%
# Visualization 
view_chicago = pdk.ViewState(latitude = 41.8781, longitude = -87.6298, zoom = 12)

my_layers = [
    # Bus Stops 
    pdk.Layer(
        type = "ScatterplotLayer", 
        data = gdf_buses, 
        pickable = True, 
        get_position = "geometry.coordinates", 
        color = "vid", 
        # get_fill_color = [255, 0, 0],
        radius_scale = 15
    )
]

chi = pdk.Deck(
    layers=my_layers, 
    initial_view_state=view_chicago, 
    map_style='light', 
)
chi.to_html("trips.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;latitude&quot;: 41.8781,
#     &quot;longitude&quot;: -87.6298,
#     &quot;zoom&quot;: 12
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;ScatterplotLayer&quot;,
#       &quot;color&quot;: &quot;@@=vid&quot;,
#       &quot;data&quot;: [
#         {
#           &quot;coordinates&quot;: [
#             &quot;-87.61434173583984&quot;,
#             &quot;41.730838775634766&quot;
#           ],
#           &quot;des&quot;: &quot;Michigan/Chicago&quot;,
#           &quot;dly&quot;: false,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               -87.61434173583984,
#               41.730838775634766
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;hdg&quot;: 359,
#           &quot;lat&quot;: 41.730838775634766,
#           &quot;lon&quot;: -87.61434173583984,
#           &quot;origtatripno&quot;: 251981024,
#           &quot;pdist&quot;: 6368,
#           &quot;pid&quot;: 18414,
#           &quot;rt&quot;: &quot;3&quot;,
#           &quot;tablockid&quot;: &quot;N4  -793&quot;,
#           &quot;tatripid&quot;: 393,
#           &quot;tmstmp&quot;: &quot;20240130 22:12&quot;,
#           &quot;unix_tmstmp&quot;: 60,
#           &quot;vid&quot;: 7936,
#           &quot;zone&quot;: &quot;&quot;
#         },
#         {
#           &quot;coordinates&quot;: [
#             &quot;-87.61438751220703&quot;,
#             &quot;41.73215103149414&quot;
#           ],
#           &quot;des&quot;: &quot;Michigan/Chicago&quot;,
#           &quot;dly&quot;: false,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               -87.61438751220703,
#               41.73215103149414
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;hdg&quot;: 358,
#           &quot;lat&quot;: 41.73215103149414,
#           &quot;lon&quot;: -87.61438751220703,
#           &quot;origtatripno&quot;: 251981859,
#           &quot;pdist&quot;: 6845,
#           &quot;pid&quot;: 18414,
#           &quot;rt&quot;: &quot;3&quot;,
#           &quot;tablockid&quot;: &quot;3 -708&quot;,
#           &quot;tatripid&quot;: 394,
#           &quot;tmstmp&quot;: &quot;20240130 22:11&quot;,
#           &quot;unix_tmstmp&quot;: 0,
#           &quot;vid&quot;: 1359,
#           &quot;zone&quot;: &quot;&quot;
#         },
#         {
#           &quot;coordinates&quot;: [
#             &quot;-87.6186294555664&quot;,
#             &quot;41.849849700927734&quot;
#           ],
#           &quot;des&quot;: &quot;Michigan/Chicago&quot;,
#           &quot;dly&quot;: false,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               -87.6186294555664,
#               41.849849700927734
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;hdg&quot;: 334,
#           &quot;lat&quot;: 41.849849700927734,
#           &quot;lon&quot;: -87.6186294555664,
#           &quot;origtatripno&quot;: 251981919,
#           &quot;pdist&quot;: 50057,
#           &quot;pid&quot;: 18414,
#           &quot;rt&quot;: &quot;3&quot;,
#           &quot;tablockid&quot;: &quot;4 -710&quot;,
#           &quot;tatripid&quot;: 391,
#           &quot;tmstmp&quot;: &quot;20240130 22:11&quot;,
#           &quot;unix_tmstmp&quot;: 0,
#           &quot;vid&quot;: 1560,
#           &quot;zone&quot;: &quot;&quot;
#         },
#         {
#           &quot;coordinates&quot;: [
#             &quot;-87.62401610729741&quot;,
#             &quot;41.86909866333008&quot;
#           ],
#           &quot;des&quot;: &quot;Michigan/Chicago&quot;,
#           &quot;dly&quot;: false,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               -87.62401610729741,
#               41.86909866333008
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;hdg&quot;: 357,
#           &quot;lat&quot;: 41.86909866333008,
#           &quot;lon&quot;: -87.62401610729741,
#           &quot;origtatripno&quot;: 251981635,
#           &quot;pdist&quot;: 58480,
#           &quot;pid&quot;: 18414,
#           &quot;rt&quot;: &quot;3&quot;,
#           &quot;tablockid&quot;: &quot;3 -757&quot;,
#           &quot;tatripid&quot;: 389,
#           &quot;tmstmp&quot;: &quot;20240130 22:12&quot;,
#           &quot;unix_tmstmp&quot;: 60,
#           &quot;vid&quot;: 1299,
#           &quot;zone&quot;: &quot;&quot;
#         },
#         {
#           &quot;coordinates&quot;: [
#             &quot;-87.61999333333333&quot;,
#             &quot;41.89386&quot;
#           ],
#           &quot;des&quot;: &quot;95th Red Line&quot;,
#           &quot;dly&quot;: false,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               -87.61999333333333,
#               41.89386
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;hdg&quot;: 178,
#           &quot;lat&quot;: 41.89386,
#           &quot;lon&quot;: -87.61999333333333,
#           &quot;origtatripno&quot;: 251980537,
#           &quot;pdist&quot;: 0,
#           &quot;pid&quot;: 18415,
#           &quot;rt&quot;: &quot;3&quot;,
#           &quot;tablockid&quot;: &quot;N4  -792&quot;,
#           &quot;tatripid&quot;: 1080326,
#           &quot;tmstmp&quot;: &quot;20240130 22:12&quot;,
#           &quot;unix_tmstmp&quot;: 60,
#           &quot;vid&quot;: 8456,
#           &quot;zone&quot;: &quot;&quot;
#         },
#         {
#           &quot;coordinates&quot;: [
#             &quot;-87.62435358220881&quot;,
#             &quot;41.896458712491125&quot;
#           ],
#           &quot;des&quot;: &quot;95th Red Line&quot;,
#           &quot;dly&quot;: false,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               -87.62435358220881,
#               41.896458712491125
#             ],
#             &quot;type&quot;: &quot;Point&quot;
#           },
#           &quot;hdg&quot;: 183,
#           &quot;lat&quot;: 41.896458712491125,
#           &quot;lon&quot;: -87.62435358220881,
#           &quot;origtatripno&quot;: 251981940,
#           &quot;pdist&quot;: 2598,
#           &quot;pid&quot;: 18415,
#           &quot;rt&quot;: &quot;3&quot;,
#           &quot;tablockid&quot;: &quot;3 -761&quot;,
#           &quot;tatripid&quot;: 1080325,
#           &quot;tmstmp&quot;: &quot;20240130 22:12&quot;,
#           &quot;unix_tmstmp&quot;: 60,
#           &quot;vid&quot;: 7951,
#           &quot;zone&quot;: &quot;&quot;
#         },
#         {
#           &quot;coordinates&quot;: [
#             &quot;-87.62384796142578&quot;,
#             &quot;41.85389928817749&quot;
#           ],
#           &quot;des&quot;: &quot;95th Red Line&quot;,
#           &quot;dly&quot;: false,
#           &quot;geometry&quot;: {
#             &quot;coordinates&quot;: [
#               -87.62384796142578,
#               41.85389928817749
#             ],
#             &quot;type&quot;: &quot;Po

# %% [markdown]
# # Try to animate plot

# %%
gdf_buses["vid"].unique()

df_bus = gdf_buses[gdf_buses["vid"] == 1259]

# df_bus.columns

# %%
df_bus = pd.DataFrame(df_bus[["coordinates", "unix_tmstmp"]])

list_coordinates = list(df_bus["coordinates"])
list_tmstmp = list(df_bus["unix_tmstmp"])

data = [[list_coordinates, list_tmstmp]]
 
# Create the pandas DataFrame
df_bus_trail = pd.DataFrame(data, columns=['coordinates', 'tmstmp'])

df_bus_trail
# Out:
#                                          coordinates  \
# 0  [[-87.643065, 41.749965], [-87.64430236816406,...
#
#                                               tmstmp
# 0  [60, 1740, 1800, 1860, 1920, 1980, 2040, 2100,...

# %%
# Visualization 
view_chicago = pdk.ViewState(latitude = 41.8781, longitude = -87.6298, 
                             zoom = 12, 
                             bearing=0, pitch=45)


layer = pdk.Layer(
    "TripsLayer", 
    df_bus_trail, 
    get_path = "coordinates", 
    get_timestamps = "tmstmp",
    current_time = 2040,
    trail_length =  600, 
    rounded = True 
)

chi = pdk.Deck(
    layers=[layer], 
    initial_view_state=view_chicago, 
    map_style='light', 
)
chi.to_html("trips.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;bearing&quot;: 0,
#     &quot;latitude&quot;: 41.8781,
#     &quot;longitude&quot;: -87.6298,
#     &quot;pitch&quot;: 45,
#     &quot;zoom&quot;: 12
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;TripsLayer&quot;,
#       &quot;currentTime&quot;: 2040,
#       &quot;data&quot;: [
#         {
#           &quot;coordinates&quot;: [
#             [
#               &quot;-87.643065&quot;,
#               &quot;41.749965&quot;
#             ],
#             [
#               &quot;-87.64430236816406&quot;,
#               &quot;41.760231018066406&quot;
#             ],
#             [
#               &quot;-87.64434051513672&quot;,
#               &quot;41.762911967742134&quot;
#             ],
#             [
#               &quot;-87.64440536499023&quot;,
#               &quot;41.76507968902588&quot;
#             ],
#             [
#               &quot;-87.64451853434245&quot;,
#               &quot;41.76874542236328&quot;
#             ],
#             [
#               &quot;-87.64458797823998&quot;,
#               &quot;41.77192152700117&quot;
#             ],
#             [
#               &quot;-87.6446304321289&quot;,
#               &quot;41.77377845301773&quot;
#             ],
#             [
#               &quot;-87.64475446758848&quot;,
#               &quot;41.77882281216708&quot;
#             ],
#             [
#               &quot;-87.64480550665604&quot;,
#               &quot;41.78163207204718&quot;
#             ],
#             [
#               &quot;-87.64491271972656&quot;,
#               &quot;41.78501076533877&quot;
#             ],
#             [
#               &quot;-87.64498138427734&quot;,
#               &quot;41.78892571585519&quot;
#             ],
#             [
#               &quot;-87.64508819580078&quot;,
#               &quot;41.79192623015373&quot;
#             ]
#           ],
#           &quot;tmstmp&quot;: [
#             60,
#             1740,
#             1800,
#             1860,
#             1920,
#             1980,
#             2040,
#             2100,
#             2160,
#             2220,
#             2280,
#             2340
#           ]
#         }
#       ],
#       &quot;getPath&quot;: &quot;@@=coordinates&quot;,
#       &quot;getTimestamps&quot;: &quot;@@=tmstmp&quot;,
#       &quot;id&quot;: &quot;5b7908cd-f081-48db-b079-b8d2a712aae6&quot;,
#       &quot;rounded&quot;: true,
#       &quot;trailLength&quot;: 600
#     }
#   ],
#   &quot;mapProvider&quot;: &quot;carto&quot;,
#   &quot;mapStyle&quot;: &quot;https://basemaps.cartocdn.com/gl/positron-gl-style/style.json&quot;,
#   &quot;views&quot;: [
#     {
#       &quot;@@type&quot;: &quot;MapView&quot;,
#       &quot;controller&quot;: true
#     }
#   ]
# };
#     const tooltip = true;
#     const customLibraries = null;
#     const configuration = null;
#
#     const deckInstance = createDeck({
#                   container,
#       jsonInput,
#       tooltip,
#       customLibraries,
#       configuration
#     });
#
#   &lt;/script&gt;
# &lt;/html&gt;"
#         ></iframe>

# %% [markdown]
# -----------------------------
# # Documentation example

# %%
"""
TripsLayer
==========

Plot of a single vehicle trip within San Francisco, fading in from the origin.

Adapted from a deck.gl documentation example.
"""

import pydeck as pdk
import pandas as pd

TRIPS_LAYER_DATA = "https://raw.githubusercontent.com/visgl/deck.gl-data/master/website/sf.trips.json"  # noqa

df = pd.read_json(TRIPS_LAYER_DATA)

df
# Out:
#                                            waypoints
# 0  [{'coordinates': [-122.39079879999997, 37.7664...

# %%
df["coordinates"] = df["waypoints"].apply(lambda f: [item["coordinates"] for item in f])
df["timestamps"] = df["waypoints"].apply(lambda f: [item["timestamp"] - 1554772579000 for item in f])

df.drop(["waypoints"], axis=1, inplace=True)
print(type(df))

df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                          coordinates  \
# 0  [[-122.39079879999997, 37.7664413], [-122.3908...
#
#                                           timestamps
# 0  [0, 9, 54, 92, 345, 402, 462, 563, 880, 1070, ...

# %%
df["coordinates"]
# Out:
# 0    [[-122.39079879999997, 37.7664413], [-122.3908...
# Name: coordinates, dtype: object

# %%
layer = pdk.Layer(
    "TripsLayer",
    df,
    get_path="coordinates",
    get_timestamps="timestamps",
    get_color=[253, 128, 93],
    opacity=0.8,
    width_min_pixels=5,
    rounded=True,
    trail_length=600,
    current_time=500,
)

view_state = pdk.ViewState(latitude=37.7749295, longitude=-122.4194155, zoom=11, bearing=0, pitch=45)

# Render
r = pdk.Deck(layers=[layer], initial_view_state=view_state)
r.to_html("trips_layer.html")
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.8.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#
# #deck-container canvas {
#   z-index: 1;
#   background: none;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const container = document.getElementById(&#x27;deck-container&#x27;);
#     const jsonInput = {
#   &quot;initialViewState&quot;: {
#     &quot;bearing&quot;: 0,
#     &quot;latitude&quot;: 37.7749295,
#     &quot;longitude&quot;: -122.4194155,
#     &quot;pitch&quot;: 45,
#     &quot;zoom&quot;: 11
#   },
#   &quot;layers&quot;: [
#     {
#       &quot;@@type&quot;: &quot;TripsLayer&quot;,
#       &quot;currentTime&quot;: 500,
#       &quot;data&quot;: [
#         {
#           &quot;coordinates&quot;: [
#             [
#               -122.39079879999997,
#               37.7664413
#             ],
#             [
#               -122.3908298,
#               37.7667706
#             ],
#             [
#               -122.39271759999997,
#               37.7667484
#             ],
#             [
#               -122.3951341,
#               37.7665964
#             ],
#             [
#               -122.409425,
#               37.7779834
#             ],
#             [
#               -122.41318080000002,
#               37.7750068
#             ],
#             [
#               -122.41619750000001,
#               37.7774034
#             ],
#             [
#               -122.42135359999997,
#               37.7770974
#             ],
#             [
#               -122.42620490000002,
#               37.8010553
#             ],
#             [
#               -122.44484019999999,
#               37.7989071
#             ],
#             [
#               -122.4493488,
#               37.801993
#             ],
#             [
#               -122.44985459999998,
#               37.8024803
#             ],
#             [
#               -122.45090290000002,
#               37.8033639
#             ],
#             [
#               -122.45116330000002,
#               37.8034643
#             ],
#             [
#               -122.44840979999998,
#               37.8046164
#             ],
#             [
#               -122.44826899999998,
#               37.8045327
#             ],
#             [
#               -122.44827479999998,
#               37.8044851
#             ],
#             [
#               -122.44846849999999,
#               37.8043839
#             ],
#             [
#               -122.44856720000001,
#               37.8040182
#             ]
#           ],
#           &quot;timestamps&quot;: [
#             0,
#             9,
#             54,
#             92,
#             345,
#             402,
#             462,
#             563,
#             880,
#             1070,
#             1117,
#             1120,
#             1127,
#             1130,
#             1166,
#             1176,
#             1181,
#             1186,
#             1200
#           ]
#         }
#       ],
#       &quot;getColor&quot;: [
#         253,
#         128,
#         93
#       ],
#       &quot;getPath&quot;: &quot;@@=coordinates&quot;,
#       &quot;getTimestamps&quot;: &quot;@@=timestamps&quot;,
#       &quot;id&quot;: &quot;1f5eb54e-0567-4bcf-8225-1391c3dfdb13&quot;,
#       &quot;opacity&quot;: 0.8,
#       &quot;rounded&quot;: true,
#       &quot;trailLength&quot;: 600,
#       &quot;widthMinPixels&quot;: 5
#     }
#   ],
#   &quot;mapProvider&quot;: &quot;carto&quot;,
#   &quot;mapStyle&quot;: &quot;https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json&quot;,
#   &quot;views&quot;: [
#     {
#       &quot;@@type&quot;: &quot;MapView&quot;,
#       &quot;controller&quot;: true
#     }
#   ]
# };
#     const tooltip = true;
#     const customLibraries = null;
#     const configuration = null;
#
#     const deckInstance = createDeck({
#                   container,
#       jsonInput,
#       tooltip,
#       customLibraries,
#       configuration
#     });
#
#   &lt;/script&gt;
# &lt;/html&gt;"
#         ></iframe>
